# %% [markdown]
# # Lab 01. Matplotlib, OpenCV and Open3d.

# %% [markdown]
# The purpose of this assignment is to learn the basic usage of matplotlib, opencv and open3d.
#
# Fill in the following functions according to the prompts. If the code you wrote is correct, you will get the same output as the cell below after you run the cell.
#
# For example, uncomment the code in the function and run the cell in **TAG0**.

# %%
# Import packages firstly.
import matplotlib.pyplot as plt
import open3d as o3d
import imageio
import numpy as np
import cv2

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ### TAG0: Example,  Read an image using imageio and opencv.
#
# Hint: Read the documentation of opencv and imageio on imread.

# %%
def read_image_cv_io(img_path):
    '''
    Input:
    img_path: string
    
    Return:
    img_cv: array, (H, W, 3)
    img_io: array, (H, W, 3)
    '''
    ##################################
    img_io = imageio.imread(img_path)
    img_cv = cv2.imread(img_path)
    return img_cv, img_io
    ##################################

img_path = 'Pikachu.jpeg'
img_cv, img_io = read_image_cv_io(img_path)
print('imageio image shape: \n', img_io.shape, '\nimage: \n', img_io)
print('opencv image shape: \n' , img_cv.shape, '\nimage: \n', img_cv)
# Out:
# imageio image shape:
#  (241, 209, 3)
# image:
#  [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# opencv image shape:
#  (241, 209, 3)
# image:
#  [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# /var/folders/5b/3474g7p13pb4yp0g39ppzntm0000gn/T/ipykernel_13965/1368278699.py:11: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_io = imageio.imread(img_path)

# %% [markdown]
# ### TAG1: Show these images using matplotlib.
#
# Hint: Please refer to the documentation of matplotlib.pyplot as  on imshow function.

# %%
def show_image(img):
    '''
    Input:
    img: array, (H, W, 3)
    '''
    ################
    # Write your code here
    plt.imshow(img)
    plt.show()
    ################
show_image(img_io)
show_image(img_cv)

# %% [markdown]
# ### TAG2: Show these images in a 1x2 subplot.

# %%
def show_images_subplot(images):
    '''
    Input: 
    images: tuple of 2 images
    '''
    ########################
    # Write your code here
    fig, axes = plt.subplots(1, 2, figsize=(9, 3))
    for i, ax in enumerate(axes):
        ax.imshow(images[i])
    plt.tight_layout()
    plt.show()
    ########################
show_images_subplot((img_io, img_cv))

# %% [markdown]
# ### TAG3: Show concated images using matplotlib
#
# Hint: Read numpy's documentation on concatenate.

# %%
def concat_images(images):
    '''
    Input: 
    images: tuple of two images, ((H, W, 3), (H, W, 3))
    Output:
    image: (H, 2*W, 3)
    '''
    ########################
    # Write your code here
    return np.hstack(images)
    ########################
    
show_image(concat_images((img_io, img_cv)))

# %% [markdown]
# ### TAG4: Plot the function of y = 2 * x^2 - 3 during [-10, 10]
#
# Hint: Read the documentation of matplotlib.pyplot on plot function.

# %%
def func(x):
    return 2 * x**2 - 3

def plot(func):
    '''
    Input: 
    func: function, x*x^2-3
    '''
    ########################
    # Write your code here
    x = np.linspace(-10, 10, 100)
    plt.plot(x, func(x))
    plt.show()
    ########################
    
plot(func)

# %% [markdown]
# ## OpenCV

# %% [markdown]
# ### TAG5: Convert and show images.
#
# Note that you need to add a waitKey function after calling imshow in opencv.
#
# Remember to destroy the windows using cv2.destroyAllWindows.

# %%
def convert_rgb_to_bgr(img):
    '''
    Input:
    img: (H, W, 3), RGB channels.
    Return:
    img: (H, W, 3), BGR channels.
    '''
    ########################
    # Write your code here
    return cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    
    ########################

def convert_rgb_to_gray(img):
    '''
    Input:
    img: (H, W, 3), RGB channels.
    Return:
    img: (H, W), Gray image.
    '''
    ########################
    # Write your code here
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    ########################

def cv_imshow(img):
    '''
    Input:
    img: (H, W, 3), BGR channels
    '''
    ########################
    # Write your code here
    cv2.imshow('TAG5', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    ########################
    
cv_imshow(convert_rgb_to_bgr(img_io))
cv_imshow(convert_rgb_to_gray(img_io))

# %% [markdown]
# ### TAG6: Read videos and show videos.
#
# Try to wait 10 ms between frames.

# %%
def read_and_show_video(video_path):
    '''
    Input: 
    video_path: string
    '''
    ########################
    # Write your code here
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Could not open the video file")
        exit()
    while True:
        ret, frame = cap.read()
        cv2.imshow('TAG6', frame)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    ########################

read_and_show_video('sfm.mp4')
cv2.destroyAllWindows()

# %% [markdown]
# ### TAG7: Write your student ID in the image and save it.

# %%
def write_student_id(img):
    '''
    Input:
    img: (H, W, 3)
    Return:
    img: (H, W, 3)
    '''
    ########################
    # Write your code here
    student_id = "3230103502"
    canvas_size = (180, 50)
    font_size = 1

    canvas = np.zeros((canvas_size[1], canvas_size[0], 3), dtype=np.uint8)
    font = cv2.FONT_HERSHEY_SIMPLEX
    text_size, _ = cv2.getTextSize(student_id, font, font_size, 2)
    text_w, text_h = text_size
    x = int((canvas_size[0] - text_w) / 2)
    y = int((canvas_size[1] + text_h) / 2)
    cv2.putText(canvas, student_id, (x, y), font, font_size, (255, 255, 255), 2)

    height, width, _ = canvas.shape
    img[10:10+height, 10:10+width] = canvas
    return img
    ########################

def write_img(img_path, img):
    '''
    Input: 
    img_path: string, 
    img: (H, W, 3), BGR channels with your student id
    '''
    ########################
    # Write your code here
    cv2.imwrite(img_path, img)
    ########################
    
write_img('result.jpeg', write_student_id(img_cv.copy()))

# %% [markdown]
# ## Open3d

# %% [markdown]
# ### TAG8: Read and visualize 3D models (in point cloud).
#
# Use the open3d.visualization.draw_geometries() function to visualize the 3D model on your PC.
# (Tip: The result will not be shown in Jupyter. Just ensure it works on your PC.)
#
# Please refer to the Open3D documentation for detailed usage.

# %%
def read_vis_model(model_path):
    '''
    Input:
    model_path: string, file path of a 3d model
    '''
    ########################
    # Write your code here
    pcd = o3d.io.read_point_cloud(model_path)
    o3d.visualization.draw_geometries([pcd])
    ########################
read_vis_model('cat.ply')
